# %%
# BMI = weight in kg / height in meter square

lbs_weight = int(input("Please, enter your weight in pounds..."))
in_height = float(input("Please, enter height in inches..."))
Eng_BMI = (703 * lbs_weight) / (in_height)**2
print(Eng_BMI)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 # BMI = weight in kg / height in meter square
# ----> 3 lbs_weight = int(input("Please, enter your weight in pounds..."))
#       4 in_height = float(input("Please, enter height in inches..."))
#       5 Eng_BMI = (703 * lbs_weight) / (in_height)**2
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
# BMI = weight in kg / height in meter square

weight = int(input("Please, enter your weight in kg..."))
height = float(input("Please, enter height in meters..."))
BMI = weight / (height)**2
#print(BMI) 

# check weight status
if BMI:
    if BMI < 18.5:
        print(BMI,':', "Under Weight")
    elif BMI >= 18.5 and BMI <= 24.9:
        print(BMI,':',"Normal")
    elif BMI >= 25.0 and BMI <= 29.9:
        print(BMI,':',"Over Weight")
    elif BMI >= 30.0 and BMI <= 34.9:
        print(BMI,':',"Obesity (Class I)")
    elif BMI >= 35.0 and BMI <= 39.9:
        print(BMI,':',"Obseity (Class II)")
    elif BMI >= 40:
        print(BMI,':',"Extreme Obseity")
# Out:
# 0.011599722991689751 : Under Weight
